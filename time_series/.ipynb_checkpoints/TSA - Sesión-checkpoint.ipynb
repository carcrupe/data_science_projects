# %% [markdown]
# <a name = "inicio"></a>

# %% [markdown]
# 1. [Introducción](#Introducción)
# 1. [Base teórica](#Base-teórica)
#     1. [Carga y transformación de datos](#Carga-y-transformación-de-datos)
#     1. [Tipos de datos temporales en pandas](#Tipos-de-datos-temporales-en-pandas)
#     1. [Herramientas de pandas](#Herramientas-de-pandas)
#         1. [Remuestreado](#Remuestreado)
#         1. [Interpolado](#Interpolado)
#         1. [Truncado](#Truncado)
#         1. [Desplazamientos](#Desplazamientos)
#         1. [Diferencias](#Diferencias)
#     1. [Conceptos matemáticos](#Conceptos-matemáticos)
#         1. [Correlación](#Correlación)
#         1. [Autocorrelación](#Autocorrelación)
#         1. [La función de autocorrelación (ACF)](#La-función-de-autocorrelación-(ACF))
#         1. [La función de autocorrelación parcial (PACF)](#La-función-de-autocorrelación-parcial-(PACF))
#         1. [Ruido blanco](#Ruido-blanco)
# 1. [Modelos ARIMA](#Modelos-ARIMA)
#     1. [El modelo Autorregresivo (AR)](#El-modelo-Autorregresivo-(AR))
#         1. [AIC y BIC](#AIC-y-BIC)
#         1. [Predicción](#Predicción)
#     1. [El modelo Moving Average (MA)](#El-modelo-Moving-Average-(MA))
#     1. [El modelo ARMA](#El-modelo-ARMA)
#     1. [Series estacionarias (stationary series)](#Series-estacionarias-(stationary-series))
#         1. [El test de Dicky-Fuller Aumentado](#El-test-de-Dicky-Fuller-Aumentado)
#         1. [Transformaciones](#Transformaciones)
#         1. [Integración](#Integración)
#     1. [Perfiles de los datos AR y MA](#Perfiles-de-los-datos-AR-y-MA)
#         1. [Datos AR](#Datos-AR)
#         1. [Datos MA](#Datos-MA)
#     1. [El modelo ARIMA](#El-modelo-ARIMA)
#     1. [El modelo ARMAX](#El-modelo-ARMAX)
#     1. [Búsqueda en bucle del mejor modelo](#Búsqueda-en-bucle-del-mejor-modelo)
#     1. [Descomposición de una serie estacional](#Descomposición-de-una-serie-estacional)
#     1. [El modelo SARIMA](#El-modelo-SARIMA)
#     1. [Diagnóstico del modelo](#Diagnóstico-del-modelo)
#     1. [Automatización del cálculo de los órdenes óptimos](#Automatización-del-cálculo-de-los-órdenes-óptimos)

# %% [markdown]
# # Introducción
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Base teórica
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ## Carga y transformación de datos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# Comencemos cargando un conjunto de datos con información temporal: el dataset <i>candy</i> con información sobre la producción de caramelos en los Estados Unidos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.style.use('seaborn')
plt.rcParams['figure.figsize'] = (15,5)

# %%
candy = pd.read_csv('candy_production.csv', sep=',')

# %%
candy.head()
# Out:
#   observation_date  IPG3113N
# 0       1972-01-01   85.6945
# 1       1972-02-01   71.8200
# 2       1972-03-01   66.0229
# 3       1972-04-01   64.5645
# 4       1972-05-01   65.0100

# %%
candy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 2 columns):
# observation_date    548 non-null object
# IPG3113N            548 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 8.7+ KB

# %%
candy = pd.read_csv('candy_production.csv', sep=',', parse_dates=['observation_date'])
candy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 548 entries, 0 to 547
# Data columns (total 2 columns):
# observation_date    548 non-null datetime64[ns]
# IPG3113N            548 non-null float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 8.7 KB

# %%
candy.rename({'observation_date': 'Date' , 'IPG3113N': 'Production'}, axis=1, inplace=True)
candy.set_index('Date', inplace=True)
candy.head()
# Out:
#             Production
# Date
# 1972-01-01     85.6945
# 1972-02-01     71.8200
# 1972-03-01     66.0229
# 1972-04-01     64.5645
# 1972-05-01     65.0100

# %%
candy= candy.to_period()

# %%
candy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 548 entries, 1972-01 to 2017-08
# Freq: M
# Data columns (total 1 columns):
# Production    548 non-null float64
# dtypes: float64(1)
# memory usage: 8.6 KB

# %%
candy.head()
# Out:
#          Production
# Date
# 1972-01     85.6945
# 1972-02     71.8200
# 1972-03     66.0229
# 1972-04     64.5645
# 1972-05     65.0100

# %%
candy.plot();

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Carga y muestra en pantalla los datos relativos al valor bursátil de IBM (dataset "ibm.txt"). Quédate apenas con el campo "Close" (además del campo que contiene la fecha, por supuesto).</div>
# </div>

# %%
ibm = pd.read_csv('ibm.txt', sep=',', parse_dates= ['Date'], usecols = ['Date', 'Close'], index_col='Date')

# %%
ibm.head()
# Out:
#              Close
# Date
# 1962-01-02  6.3378
# 1962-01-03  6.3963
# 1962-01-04  6.3295
# 1962-01-05  6.2041
# 1962-01-08  6.0870

# %%
ibm.plot();

# %% [markdown]
# ## Tipos de datos temporales en pandas
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# #### La clase Timestamp

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timestamp.html

# %%
pd.Timestamp("1/2/2019")
# Out:
# Timestamp('2019-01-02 00:00:00')

# %%
pd.Timestamp(2019, 2, 1)
# Out:
# Timestamp('2019-02-01 00:00:00')

# %%
pd.Timestamp(2019, 2, 1, 16, 17, 22)
# Out:
# Timestamp('2019-02-01 16:17:22')

# %%
pd.Timestamp(year = 2019, month = 10, day = 28, hour = 16, minute = 56, second = 12,
                 microsecond = 13, nanosecond = 16)
# Out:
# Timestamp('2019-10-28 16:56:12.000013016')

# %%
from datetime import date

# %%
pd.Timestamp(date(2019, 8, 26))
# Out:
# Timestamp('2019-08-26 00:00:00')

# %%
d = pd.Timestamp(year = 2019, month = 10, day = 28, hour = 16, minute = 56, second = 12,
                 microsecond = 13, nanosecond = 16)
d
# Out:
# Timestamp('2019-10-28 16:56:12.000013016')

# %%
print(d.year)
print(d.month)
print(d.day)
print(d.hour)
print(d.minute)
print(d.second)
print(d.microsecond)
print(d.nanosecond)
# Out:
# 2019
# 10
# 28
# 16
# 56
# 12
# 13
# 16

# %%
print(d.quarter)
print(d.week)
print(d.dayofweek)
print(d.dayofyear)
print(d.day_name())
print(d.month_name())
# Out:
# 4
# 44
# 0
# 301
# Monday
# October

# %% [markdown]
# #### La clase Period

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Period.html

# %%
p = pd.Period("2017-01")
p
# Out:
# Period('2017-01', 'M')

# %%
p.start_time
# Out:
# Timestamp('2017-01-01 00:00:00')

# %%
p.end_time
# Out:
# Timestamp('2017-01-31 23:59:59.999999999')

# %%
p.asfreq("D")
# Out:
# Period('2017-01-31', 'D')

# %%
p = pd.Period("2017-05-23")
p.asfreq("M")
# Out:
# Period('2017-05', 'M')

# %%
p.asfreq("D")
# Out:
# Period('2017-05-23', 'D')

# %%
pd.Period("2018-05").to_timestamp()
# Out:
# Timestamp('2018-05-01 00:00:00')

# %%
p = pd.Period("2017-05-23")
p + 2
# Out:
# Period('2017-05-25', 'D')

# %%
p = pd.Period("2017-05-23")
q = pd.Period("2017-05-28")
q - p
# Out:
# <5 * Days>

# %% [markdown]
# #### La clase Timedelta

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Timedelta.html

# %%
d = pd.Timedelta(weeks = 1, days = 2, hours = 3, minutes = 4, seconds = 5, milliseconds = 6,
                 microseconds = 7, nanoseconds = 8)
d
# Out:
# Timedelta('9 days 03:04:05.006007')

# %%
print(d.days)
print(d.seconds)
print(d.microseconds)
print(d.nanoseconds)
# Out:
# 9
# 11045
# 6007
# 8

# %%
pd.Timedelta("1 day 1 second")
# Out:
# Timedelta('1 days 00:00:01')

# %%
pd.Timedelta("1 day 1 millisecond")
# Out:
# Timedelta('1 days 00:00:00.001000')

# %%
pd.Timedelta("1 hour")
# Out:
# Timedelta('0 days 01:00:00')

# %%
pd.Timedelta("2 hour")
# Out:
# Timedelta('0 days 02:00:00')

# %%
pd.Timedelta("2 hours")
# Out:
# Timedelta('0 days 02:00:00')

# %%
pd.Timedelta("2.3 hours")
# Out:
# Timedelta('0 days 02:18:00')

# %%
pd.Timestamp(2019, 8, 25, 18, 49) + pd.Timedelta("3 hours")
# Out:
# Timestamp('2019-08-25 21:49:00')

# %% [markdown]
# #### La clase date_range

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.date_range.html

# %%
pd.date_range("August, 28 2018", periods = 5, freq = "M")
# Out:
# DatetimeIndex(['2018-08-31', '2018-09-30', '2018-10-31', '2018-11-30',
#                '2018-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range("August, 28 2018", periods = 5, freq = "D")
# Out:
# DatetimeIndex(['2018-08-28', '2018-08-29', '2018-08-30', '2018-08-31',
#                '2018-09-01'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start = date(2019, 8, 13), end = date(2019, 9, 21), freq = "W")
# Out:
# DatetimeIndex(['2019-08-18', '2019-08-25', '2019-09-01', '2019-09-08',
#                '2019-09-15'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start = "2018-01-1", end = "2019-12-31", freq = "MS")
# Out:
# DatetimeIndex(['2018-01-01', '2018-02-01', '2018-03-01', '2018-04-01',
#                '2018-05-01', '2018-06-01', '2018-07-01', '2018-08-01',
#                '2018-09-01', '2018-10-01', '2018-11-01', '2018-12-01',
#                '2019-01-01', '2019-02-01', '2019-03-01', '2019-04-01',
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
from datetime import datetime

# %%
pd.date_range(start = datetime.today(), periods = 5, freq = "H")
# Out:
# DatetimeIndex(['2020-02-08 10:12:55.197891', '2020-02-08 11:12:55.197891',
#                '2020-02-08 12:12:55.197891', '2020-02-08 13:12:55.197891',
#                '2020-02-08 14:12:55.197891'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.date_range(start = "2019-1-1", end = "2019-3-1", periods = 4)
# Out:
# DatetimeIndex(['2019-01-01 00:00:00', '2019-01-20 16:00:00',
#                '2019-02-09 08:00:00', '2019-03-01 00:00:00'],
#               dtype='datetime64[ns]', freq=None)

# %%
pd.date_range(start = "2019-8-1", end = "2019-8-31", freq = "B")
# Out:
# DatetimeIndex(['2019-08-01', '2019-08-02', '2019-08-05', '2019-08-06',
#                '2019-08-07', '2019-08-08', '2019-08-09', '2019-08-12',
#                '2019-08-13', '2019-08-14', '2019-08-15', '2019-08-16',
#                '2019-08-19', '2019-08-20', '2019-08-21', '2019-08-22',
#                '2019-08-23', '2019-08-26', '2019-08-27', '2019-08-28',
#                '2019-08-29', '2019-08-30'],
#               dtype='datetime64[ns]', freq='B')

# %%
pd.date_range(start = "2019-8-1", end = "2019-8-31", freq = "B") + pd.Timedelta("3 hours")

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
#     <strong>EJERCICIO</strong>
# Crea un dataframe df con 12 fechas consecutivas (interpretadas como puntos en el tiempo) a partir del 1 de enero de 2019 en el índice y una columna "Value" con valores aleatorios:
# </div>

# %%
index = pd.date_range(start= '2019-01-1', periods = 12, freq='D')

# %%
df_dates = pd.DataFrame({'Values': np.random.randint(0,10,12)}, index= index )
df_dates
# Out:
#             Values
# 2019-01-01       0
# 2019-01-02       0
# 2019-01-03       8
# 2019-01-04       1
# 2019-01-05       2
# 2019-01-06       8
# 2019-01-07       4
# 2019-01-08       9
# 2019-01-09       6
# 2019-01-10       0
# 2019-01-11       4
# 2019-01-12       5

# %% [markdown]
# #### La clase period_range

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.period_range.html

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# Crea un dataframe df con 6 horas consecutivas (interpretadas como períodos) a partir de las 6 de la tarde del 11 de marzo de 2019 en el índice y una columna "Value" con valores aleatorios:
# </div>

# %%
p = pd.period_range(start = '2019-03-1 T18:0:0', periods = 6 , freq = 'H')
p
# Out:
# PeriodIndex(['2019-03-01 18:00', '2019-03-01 19:00', '2019-03-01 20:00',
#              '2019-03-01 21:00', '2019-03-01 22:00', '2019-03-01 23:00'],
#             dtype='period[H]', freq='H')

# %% [markdown]
# ## Herramientas de pandas
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ### Remuestreado
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.resample.html

# %% [markdown]
# Leamos el dataset *global_temperature_monthly.csv*. ¿Las muestras están distribuidas tal y como necesitamos?

# %% [markdown]
# Esto es especialmente útil si las fechas no son periódicas, como ocurre en el dataset months.csv:

# %%
temp = pd.read_csv('global_temperature_monthly.csv', parse_dates=['Date'], index_col='Date')

# %%
temp.head()
# Out:
#              Source    Mean
# Date
# 2016-12-06     GCAG  0.7895
# 2016-12-06  GISTEMP  0.8100
# 2016-11-06     GCAG  0.7504
# 2016-11-06  GISTEMP  0.9300
# 2016-10-06     GCAG  0.7292

# %%
temp.Source.unique()
# Out:
# array(['GCAG', 'GISTEMP'], dtype=object)

# %%
temp.resample('Y').mean().plot()
temp.resample('M').mean().plot(color = 'r')

# %%
data = pd.read_csv("months.csv", parse_dates = ["date"], index_col = "date")
data
# Out:
#             value
# date
# 2019-01-04      8
# 2019-01-16      4
# 2019-03-02      9
# 2019-03-03      3
# 2019-03-11      4
# 2019-04-02      7
# 2019-06-06      3
# 2019-06-26      5
# 2019-07-18      1
# 2019-07-23      6

# %%
data.resample('M').sum()
# Out:
#             value
# date
# 2019-01-31     12
# 2019-02-28      0
# 2019-03-31     16
# 2019-04-30      7
# 2019-05-31      0
# 2019-06-30      8
# 2019-07-31      7

# %% [markdown]
# ### Interpolado
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.interpolate.html

# %% [markdown]
# Una herramienta muy útil es la que nos permite sustituir valores nulos por el resultado de interpolar los valores existentes, lo que puede ocurrir si aplicamos a un dataframe una frecuencia: df = df.asfreq("D"). Veámoslo en el dataset de days.csv

# %%
days = pd.read_csv('days.csv', parse_dates=['date'], index_col='date')
days
# Out:
#             value
# date
# 2019-01-01      8
# 2019-01-02      4
# 2019-01-04      9
# 2019-01-05      3
# 2019-01-08      4
# 2019-01-09      7

# %%
days = days.asfreq('D')
days
# Out:
#             value
# date
# 2019-01-01    8.0
# 2019-01-02    4.0
# 2019-01-03    NaN
# 2019-01-04    9.0
# 2019-01-05    3.0
# 2019-01-06    NaN
# 2019-01-07    NaN
# 2019-01-08    4.0
# 2019-01-09    7.0

# %%
days.interpolate()
# Out:
#                value
# date
# 2019-01-01  8.000000
# 2019-01-02  4.000000
# 2019-01-03  6.500000
# 2019-01-04  9.000000
# 2019-01-05  3.000000
# 2019-01-06  3.333333
# 2019-01-07  3.666667
# 2019-01-08  4.000000
# 2019-01-09  7.000000

# %% [markdown]
# ### Truncado
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.truncate.html

# %% [markdown]
# Otro útil método es .truncate(), que nos permite eliminar los índices anteriores y/o posteriores a uno dado.
#
# **IMPORTANTE**: El índice deberá estar ordenado.

# %%
s= pd.Series(np.random.randint(0,10,10))
s
# Out:
# 0    3
# 1    8
# 2    8
# 3    8
# 4    3
# 5    4
# 6    3
# 7    0
# 8    4
# 9    5
# dtype: int64

# %%
s.truncate(before= 5)
# Out:
# 5    4
# 6    8
# 7    7
# 8    8
# 9    9
# dtype: int64

# %%
s.truncate(before= 5, after=7)
# Out:
# 5    4
# 6    3
# 7    0
# dtype: int64

# %% [markdown]
# Podemos aplicarlo a candy... tanto con períodos mensuales como anuales.

# %%
candy.head()
# Out:
#          Production
# Date
# 1972-01     85.6945
# 1972-02     71.8200
# 1972-03     66.0229
# 1972-04     64.5645
# 1972-05     65.0100

# %%
candy.truncate(before = '2000').head()
# Out:
#          Production
# Date
# 2000-01    123.1325
# 2000-02    119.7423
# 2000-03    113.9508
# 2000-04    115.9481
# 2000-05    108.7202

# %%
candy.truncate(before = '2000-5').head()
# Out:
#          Production
# Date
# 2000-05    108.7202
# 2000-06    114.2071
# 2000-07    111.8737
# 2000-08    117.9027
# 2000-09    125.6499

# %% [markdown]
# ### Desplazamientos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# El método .shift() aplicado a una serie o a un dataframe nos permite desplazarlo en una dirección (por defecto hacia abajo):
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html

# %%
data = pd.DataFrame(np.random.randint(0, 10, 20).reshape(4, -1), columns = list("ABCDE"))
data
# Out:
#    A  B  C  D  E
# 0  6  5  2  9  8
# 1  2  7  5  1  6
# 2  9  2  3  5  0
# 3  0  7  9  8  2

# %%
data.shift()
# Out:
#      A    B    C    D    E
# 0  NaN  NaN  NaN  NaN  NaN
# 1  6.0  5.0  2.0  9.0  8.0
# 2  2.0  7.0  5.0  1.0  6.0
# 3  9.0  2.0  3.0  5.0  0.0

# %%
data.shift(2, axis=1)
# Out:
#     A   B    C    D    E
# 0 NaN NaN  6.0  5.0  2.0
# 1 NaN NaN  2.0  7.0  5.0
# 2 NaN NaN  9.0  2.0  3.0
# 3 NaN NaN  0.0  7.0  9.0

# %% [markdown]
# ### Diferencias
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.diff.html

# %% [markdown]
# El método .diff() permite calcular la diferencia de las columnas o filas de un dataframe:

# %%
data
# Out:
#    A  B  C  D  E
# 0  6  5  2  9  8
# 1  2  7  5  1  6
# 2  9  2  3  5  0
# 3  0  7  9  8  2

# %%
data.diff()
# Out:
#      A    B    C    D    E
# 0  NaN  NaN  NaN  NaN  NaN
# 1 -4.0  2.0  3.0 -8.0 -2.0
# 2  7.0 -5.0 -2.0  4.0 -6.0
# 3 -9.0  5.0  6.0  3.0  2.0

# %%
s = pd.Series([2, 5, 4, 7, 6, 1, 5, 3])
s
# Out:
# 0    2
# 1    5
# 2    4
# 3    7
# 4    6
# 5    1
# 6    5
# 7    3
# dtype: int64

# %%
s.diff()
# Out:
# 0    NaN
# 1    3.0
# 2   -1.0
# 3    3.0
# 4   -1.0
# 5   -5.0
# 6    4.0
# 7   -2.0
# dtype: float64

# %% [markdown]
# ## Conceptos matemáticos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ### Correlación
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# Alta correlación (positiva):

# %%
r = pd.Series([3.4, 8.9, 6.8, 0.6, 4.6, 8.4, 7.8, 1.3, 5.0 , 0.7])
s = pd.Series([6.4, 9.8, 8.8, 4.8, 6.9, 9.4, 7.8, 3.7, 7.7, 6.0 ])

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(r)
ax[0].plot(s)
ax[1].scatter(r,s)
print(r.corr(s))
# Out:
# 0.9215849991769304

# %% [markdown]
# Alta correlación (negativa):

# %%
r = pd.Series([7.5, 8.8, 8.2, 4.5, 5.5, 6.4, 9.8, 6.2, 4.5, 8.7])
s = pd.Series([4.4, 5.6, 6.1, 9.9, 8.3, 8.3, 2.2, 8.4, 7.4, 4.3])

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(r)
ax[0].plot(s)
ax[1].scatter(r,s)
print(r.corr(s))
# Out:
# -0.8725229717753339

# %% [markdown]
# Baja correlación:

# %%
r = pd.Series([8.4, 5.3, 3.2, 9. , 1.2, 4.1, 7.3, 7.2, 2.8, 3.7])
s = pd.Series([6.3, 9. , 4.3, 5.5, 6.8, 9.6, 4.4, 1.6, 5.6, 0.5])

# %%
fig, ax = plt.subplots(1,2)
ax[0].plot(r)
ax[0].plot(s)
ax[1].scatter(r,s)
print(r.corr(s))
# Out:
# -0.10630510433176735

# %% [markdown]
# http://tylervigen.com/view_correlation?id=1703

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Muestra en una gráfica la evolución de los valores bursátiles de IBM y Apple, y calcula la correlación entre ellos. Quédate solo con la columna "Close" (además de la que contiene la etiqueta temporal).</div>
# </div>

# %%
apple = pd.read_csv('aapl.txt', parse_dates=['Date'], index_col='Date')
apple_close = apple['Close']

ibm.plot()
apple_close.plot()

# %% [markdown]
# ### Autocorrelación
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
s = pd.Series(np.random.randint(0, 5, (10, )))
s
# Out:
# 0    3
# 1    3
# 2    2
# 3    2
# 4    4
# 5    2
# 6    0
# 7    3
# 8    0
# 9    1
# dtype: int64

# %%
s.corr(s.shift(1))
# Out:
# -0.05970149253731348

# %%
s.autocorr(1)
# Out:
# -0.05970149253731348

# %%
s.autocorr(0)
# Out:
# 1.0

# %% [markdown]
# ¿Qué tipo de series mostrarán autocorrelación alta para algún lag?

# %%
x = np.linspace(0, 12, 24)
y = np.sin(x)
y = pd.Series(y)

# %%
plt.plot(y);
print(y.corr(y))
# Out:
# 1.0

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Calcula la autocorrelación de la función senoidal y para los lags entre 0 y 19</div>
# </div>

# %%
n=6
plt.plot(y);
plt.plot(y.shift(n))
print(y.autocorr(n))
# Out:
# -0.999932907269958

# %%
for i in range(20):
    print(i, y.autocorr(i))
# Out:
# 0 1.0
# 1 0.8769662829481312
# 2 0.5582079972438304
# 3 0.10295090073607362
# 4 -0.4156445200785021
# 5 -0.8400800103410611
# 6 -0.999932907269958
# 7 -0.8754213232665885
# 8 -0.5554622541938353
# 9 -0.10504434514224271
# 10 0.41287463084238285
# 11 0.8394041433021404
# 12 0.9997525833198959
# 13 0.8968791741912433
# 14 0.6497962146967481
# 15 0.32657217479330264
# 16 -0.09108626980054128
# 17 -0.631830220760804
# 18 -0.9982702377583391
# 19 -0.5889255730259966

# %% [markdown]
# ### La función de autocorrelación (ACF)
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# Tanto en acf como en plot_acf deberemos usar el parámetro unbiased = True para evitar que influya el número limitado de muestras.

# %%
from statsmodels.tsa.stattools import acf

# %%
acf_result = acf(y, unbiased=True)
plt.bar(range(len(acf_result)),acf_result);
# Out:
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
plot_acf(y)

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Muestra en pantalla la función de autocorrelación de candy para los 50 primeros lags. Interpreta el resultado</div>
# </div>

# %%
acf(candy, nlags=50, unbiased=True)
# Out:
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/stattools.py:541: FutureWarning: fft=True will become the default in a future version of statsmodels. To suppress this warning, explicitly set fft=False.
#   warnings.warn(msg, FutureWarning)
# array([1.        , 0.87560658, 0.68557687, 0.45532749, 0.28892665,
#        0.17489249, 0.14280705, 0.15934038, 0.26357414, 0.41853479,
#        0.63762945, 0.81866476, 0.92313245, 0.81084163, 0.62790477,
#        0.39811994, 0.2357806 , 0.12629189, 0.09184867, 0.10924679,
#        0.21573792, 0.37029365, 0.59421218, 0.77585068, 0.8776318 ,
#        0.76909022, 0.58781728, 0.35915339, 0.2038564 , 0.09626858,
#        0.06435725, 0.08652444, 0.19286052, 0.34924027, 0.57166341,
#        0.7508963 , 0.84898797, 0.74257229, 0.55641792, 0.32390697,
#        0.16700908, 0.05053568, 0.01461535, 0.03455827, 0.13683394,
#        0.29315381, 0.51804683, 0.6903105 , 0.79253746, 0.69029415,
#        0.51052584])

# %%
plot_acf(candy , lags=50, unbiased=True)

# %% [markdown]
# ### La función de autocorrelación parcial (PACF)
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# Para evitar errores, podemos vernos obligados a especificar el método de cálculo: method = "ywm"

# %%
from statsmodels.tsa.stattools import pacf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
pacf(candy)
# Out:
# array([ 1.00000000e+00,  8.75606579e-01, -3.47644452e-01, -2.40146453e-01,
#         2.27571526e-01,  7.33969929e-03,  1.15796036e-01,  8.53614997e-02,
#         3.44682661e-01,  2.92129400e-01,  4.93277421e-01,  3.42629591e-01,
#         3.40953995e-01, -6.41358578e-01, -1.31078590e-01, -1.30445050e-01,
#         7.43905927e-02,  8.98089192e-02,  9.07445795e-03,  7.83753025e-02,
#         7.26744183e-02, -1.48921734e-05,  1.53684484e-01,  3.70602502e-02,
#         1.01644795e-01, -2.89529578e-01, -8.20439564e-02, -3.15412977e-02,
#         1.44899169e-01,  4.13381768e-02,  1.03366842e-01,  1.01552049e-01,
#        -3.05579101e-02, -8.26961628e-03, -6.89532613e-02,  3.26702919e-03,
#         2.69871626e-02, -1.23419972e-01, -1.36816404e-01, -9.38328668e-02,
#         3.99590647e-02])

# %%
plot_pacf(candy)

# %% [markdown]
# ### Ruido blanco
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
s = np.random.rand(500)
plt.plot(s, linestyle='', marker='.');

# %%
plot_acf(s)

# %%
s = np.random.randn(500)
plt.plot(s, linestyle='', marker='.');

# %% [markdown]
# # Modelos ARIMA
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ## El modelo Autorregresivo (AR)
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# <strong>R<sub>t</sub> = a<sub>1</sub>.R<sub>t-1</sub> + a<sub>2</sub>.R<sub>t-2</sub> + ... + a<sub>p</sub>.R<sub>t-p</sub> + &epsilon;<sub>t</sub></strong>
#
# p: orden del modelo
#
# AR(1): R<sub>t</sub> = a<sub>1</sub>.R<sub>t-1</sub> + &epsilon;<sub>t</sub>
#
# AR(2): R<sub>t</sub> = a<sub>1</sub>.R<sub>t-1</sub> + a<sub>2</sub>.R<sub>t-2</sub> + &epsilon;<sub>t</sub>
#
# AR(p): R<sub>t</sub> = a<sub>1</sub>.R<sub>t-1</sub> + a<sub>2</sub>.R<sub>t-2</sub> + ... + a<sub>p</sub>.R<sub>t-p</sub> + &epsilon;<sub>t</sub>

# %% [markdown]
# Candy - AR(2):

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX

# %%
model = SARIMAX(candy, order=(2,0,0)).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:             Production   No. Observations:                  548
# Model:               SARIMAX(2, 0, 0)   Log Likelihood               -1965.427
# Date:                Sat, 08 Feb 2020   AIC                           3936.854
# Time:                        12:21:46   BIC                           3949.773
# Sample:                    01-31-1972   HQIC                          3941.904
#                          - 08-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          1.2575      0.056     22.553      0.000       1.148       1.367
# ar.L2         -0.2624      0.057     -4.638      0.000      -0.373      -0.152
# sigma2        75.6479      3.187     23.739      0.000      69.402      81.894
# ===================================================================================
# Ljung-Box (Q):                     1697.19   Jarque-Bera (JB):               125.89
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.50   Skew:                             0.28
# Prob(H) (two-sided):                  0.00   Kurtosis:                         5.28
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model.aic
# Out:
# 3936.8543798817777

# %%
model.bic
# Out:
# 3949.773205742622

# %% [markdown]
# ### AIC y BIC
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Compara los valores de AIC y BIC para los modelos AR de orden 1 y 2 aplicados a candy.</div>
# </div>

# %%
model_1 = SARIMAX(candy, order=(1,0,0)).fit()
model_2 = SARIMAX(candy, order=(2,0,0)).fit()

# %%
print(model_1.aic - model_2.aic)
# Out:
# 36.82539237271112

# %%
print(model_1.bic - model_2.bic)
# Out:
# 32.5191170857629

# %% [markdown]
# ### Predicción
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
prediction = model.get_forecast(steps=24)
prediction

# %%
prediction.predicted_mean[:5]
# Out:
# 2017-09    116.518645
# 2017-10    116.597866
# 2017-11    116.052706
# 2017-12    115.346362
# 2018-01    114.601152
# Freq: M, dtype: float64

# %%
prediction.conf_int().head()
# Out:
#          lower Production  upper Production
# 2017-09         99.471696        133.565593
# 2017-10         89.208997        143.986735
# 2017-11         80.616458        151.488954
# 2017-12         73.289381        157.403342
# 2018-01         66.863888        162.338415

# %%
candy.truncate(before= '2005').plot()
prediction.predicted_mean.plot()

# %% [markdown]
# Podemos acceder a los valores predichos para los datos en los que el modelo se ha entreado con el atributo .fittedvalues:

# %%
model.fittedvalues

# %% [markdown]
# Es posible calcular el error cuadrático medio -por ejemplo-:

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(candy.production, model.fittedvalues)

# %% [markdown]
# ## El modelo Moving Average (MA)
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# <strong>R<sub>t</sub> = m<sub>1</sub>.&epsilon;<sub>t-1</sub> + m<sub>2</sub>.&epsilon;<sub>t-2</sub> + ... + m<sub>q</sub>.&epsilon;<sub>t-q</sub> + &epsilon;<sub>t</sub></strong>
#
# p: orden del modelo:
#
# MA(1): R<sub>t</sub> = m<sub>1</sub>.&epsilon;<sub>t-1</sub> + &epsilon;<sub>t</sub>
#
# MA(2): R<sub>t</sub> = m<sub>1</sub>.&epsilon;<sub>t-1</sub> + m<sub>2</sub>.&epsilon;<sub>t-2</sub> + &epsilon;<sub>t</sub>
#
# MA(q): R<sub>t</sub> = m<sub>1</sub>.&epsilon;<sub>t-1</sub> + m<sub>2</sub>.&epsilon;<sub>t-2</sub> + ... + m<sub>p</sub>.&epsilon;<sub>t-p</sub> + &epsilon;<sub>t</sub>

# %% [markdown]
# Candy - MA(3):

# %%
model_s = SARIMAX(candy, order=(0,0,3)).fit()

# %%
model_s.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Statespace Model Results
# ==============================================================================
# Dep. Variable:             Production   No. Observations:                  548
# Model:               SARIMAX(0, 0, 3)   Log Likelihood               -2719.637
# Date:                Sat, 08 Feb 2020   AIC                           5447.274
# Time:                        12:40:03   BIC                           5464.499
# Sample:                    01-31-1972   HQIC                          5454.007
#                          - 08-31-2017
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          1.7975      0.070     25.708      0.000       1.660       1.935
# ma.L2          1.2426      0.115     10.787      0.000       1.017       1.468
# ma.L3          0.1481      0.069      2.141      0.032       0.013       0.284
# sigma2      1173.1169     90.315     12.989      0.000     996.104    1350.130
# ===================================================================================
# Ljung-Box (Q):                     3510.60   Jarque-Bera (JB):                 9.49
# Prob(Q):                              0.00   Prob(JB):                         0.01
# Heteroskedasticity (H):               1.16   Skew:                             0.08
# Prob(H) (two-sided):                  0.32   Kurtosis:                         2.38
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
prediction = model_s.get_forecast(steps = 24)
lower = prediction.conf_int()["lower Production"]
upper = prediction.conf_int()["upper Production"]

# %%
fig, ax = plt.subplots()
candy.truncate(before = "2005").plot(ax = ax)
prediction.predicted_mean.plot(ax = ax)
ax.fill_between(lower.index, lower, upper, alpha = 0.4)
plt.show()

# %% [markdown]
# ## El modelo ARMA
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ARMA(1, 1): R<sub>t</sub> = a<sub>1</sub>.R<sub>t-1</sub> + m<sub>1</sub>.&epsilon;<sub>t-1</sub> + &epsilon;<sub>t</sub>
#
# ARMA(p, q): AR(p): R<sub>t</sub> = a<sub>1</sub>.R<sub>t-1</sub> + a<sub>2</sub>.R<sub>t-2</sub> + a<sub>p</sub>.R<sub>t-p</sub> + R<sub>t</sub> = m<sub>1</sub>.&epsilon;<sub>t-1</sub> + m<sub>2</sub>.&

# %% [markdown]
# Candy - ARMA(2, 3):

# %%
prediction = model.get_forecast(steps = 12)
lower = prediction.conf_int()["lower Production"]
upper = prediction.conf_int()["upper Production"]

# %%
fig, ax = plt.subplots()
candy.truncate(before = "2010").plot(ax = ax)
prediction.predicted_mean.plot(ax = ax)
ax.fill_between(lower.index, lower, upper, alpha = 0.4)
plt.show()

# %% [markdown]
# ## Series estacionarias (stationary series)
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### El test de Dicky-Fuller Aumentado
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(candy.Production)
# Out:
# (-1.8870498112252763,
#  0.3381775973004313,
#  14,
#  533,
#  {'1%': -3.442678467240966,
#   '5%': -2.8669778698997543,
#   '10%': -2.5696661916864083},
#  3012.789090974259)

# %%
candy_diff= candy.diff()
candy_diff.dropna(inplace=True)
candy_diff.plot()

# %%
adfuller(candy_diff.Production)
# Out:
# (-6.119511504715748,
#  8.92558420357052e-08,
#  13,
#  533,
#  {'1%': -3.442678467240966,
#   '5%': -2.8669778698997543,
#   '10%': -2.5696661916864083},
#  3009.6697664167204)

# %%
model = SARIMAX(candy_diff, order=(2,0,3)).fit()
# Out:
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
prediction = model.get_forecast(24)

# %%
candy.truncate(before='2005').plot()
prediction.predicted_mean.plot()

# %%
real_prediction = np.cumsum(prediction.predicted_mean) + candy.iloc[-1].values

# %%
candy.truncate(before='2005').plot()
real_prediction.plot()

# %% [markdown]
# ### Transformaciones
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ###### Diferencia

# %% [markdown]
# ###### Porcentaje de cambio

# %% [markdown]
# Apliquémoslo al dataset AirPassengers.csv.

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Carga el dataset AirPassengers.csv, aplica el método visto y pásale el test de Dicky-Fuller aumentado ¿es estacionario?</div>
# </div>

# %%
air = pd.read_csv('AirPassengers.csv', parse_dates=['Month'])
air.rename({'#Passengers': 'passengers'}, axis=1, inplace=True)
air.set_index('Month', inplace=True)
air.head()
# Out:
#             passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121

# %%
air.plot()

# %%
adfuller(air.passengers)
# Out:
# (0.8153688792060544,
#  0.9918802434376411,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  996.692930839019)

# %%
air_pct = air.pct_change().dropna()
air_pct.head()
# Out:
#             passengers
# Month
# 1949-02-01    0.053571
# 1949-03-01    0.118644
# 1949-04-01   -0.022727
# 1949-05-01   -0.062016
# 1949-06-01    0.115702

# %%
air_pct.plot()

# %%
adfuller(air_pct.passengers)
# Out:
# (-2.9261089075453897,
#  0.04239503972523894,
#  14,
#  128,
#  {'1%': -3.4825006939887997,
#   '5%': -2.884397984161377,
#   '10%': -2.578960197753906},
#  -425.9255544019345)

# %% [markdown]
# ###### Logaritmo

# %%
air_log=np.log(air)
air_log.head()
# Out:
#             passengers
# Month
# 1949-01-01    4.718499
# 1949-02-01    4.770685
# 1949-03-01    4.882802
# 1949-04-01    4.859812
# 1949-05-01    4.795791

# %%
air_log.plot();

# %%
adfuller(air_log.passengers)
# Out:
# (-1.7170170891069625,
#  0.4223667747703904,
#  13,
#  130,
#  {'1%': -3.4816817173418295,
#   '5%': -2.8840418343195267,
#   '10%': -2.578770059171598},
#  -445.3990312497209)

# %% [markdown]
# ###### Otras funciones

# %% [markdown]
# ###### Funciones combinadas

# %% [markdown]
# air_passengers + log + diff

# %%
air_diff_log = np.log(air).diff().dropna()
air_diff_log.head()
# Out:
#             passengers
# Month
# 1949-02-01    0.052186
# 1949-03-01    0.112117
# 1949-04-01   -0.022990
# 1949-05-01   -0.064022
# 1949-06-01    0.109484

# %%
air_diff_log.plot()

# %%
adfuller(air_diff_log.passengers)
# Out:
# (-2.7171305983881595,
#  0.07112054815085424,
#  14,
#  128,
#  {'1%': -3.4825006939887997,
#   '5%': -2.884397984161377,
#   '10%': -2.578960197753906},
#  -440.35846985568105)

# %% [markdown]
# ### Integración
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ## Perfiles de los datos AR y MA
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
from statsmodels.tsa.arima_process import arma_generate_sample

# %% [markdown]
# ### Datos AR
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Muestra la funciones de autocorrelación y de autocorrelación parcial para datos de un modelo AR(2)</div>
# </div>

# %%
sample = arma_generate_sample([1,-0.7],[1, 0],1000)

# %%
plot_acf(sample);

# %%
plot_pacf(sample);

# %% [markdown]
# ### Datos MA
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Muestra la funciones de autocorrelación y de autocorrelación parcial para datos de un modelo MA(2)</div>
# </div>

# %% [markdown]
# ## El modelo ARIMA
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# Candy - ARIMA(3, 1, 2)

# %%
model = SARIMAX(candy, order=(3,1,2)).fit()

# %%
prediction = model.get_forecast(steps = 24)
lower = prediction.conf_int()["lower Production"]
upper = prediction.conf_int()["upper Production"]

# %%
fig, ax = plt.subplots()
candy.truncate(before = "2005").plot(ax = ax)
prediction.predicted_mean.plot(ax = ax)
ax.fill_between(lower.index, lower, upper, alpha = 0.4)
plt.show()

# %% [markdown]
# ## El modelo ARMAX
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# ARMA(1,1): y<sub>t</sub> = a<sub>1</sub>y<sub>t-1</sub> + m<sub>1</sub>&epsilon;<sub>t-1</sub> + &epsilon;<sub>t</sub>
#
# ARMAX(1,1): y<sub>t</sub> = a<sub>1</sub>y<sub>t-1</sub> + m<sub>1</sub>&epsilon;<sub>t-1</sub> + &epsilon;<sub>t</sub> + x<sub>1</sub>z<sub>t</sub>

# %%
ventas = pd.Series([10, 22, 15, 10, 25, 30, 18])

# %%
festivos = pd.Series([1, 0, 0, 0, 0, 1, 1])

# %%
model = SARIMAX(ventas,order=(2,0,1), exog=festivos).fit()
# Out:
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'

# %%
prediction = model.get_forecast(steps=2,exog=pd.DataFrame([0,0]))

# %%
lower = prediction.conf_int()["lower y"]
upper = prediction.conf_int()["upper y"]

# %%
fig, ax = plt.subplots()
ventas.plot(ax = ax)
prediction.predicted_mean.plot(ax = ax, label = "Forecast")
ax.fill_between(lower.index, lower, upper, alpha = 0.4)
plt.show()

# %% [markdown]
# <div style="background:#0099cc;padding:20px;color:#ffffff">
# <strong>EJERCICIO</strong>
# <div>Repite el ejercicio suponiendo que ambos días van a ser festivos</div>
# </div>

# %% [markdown]
# ## Búsqueda en bucle del mejor modelo
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
best_aic = 999999
for p in range(4):
    for q in range(4):
        for d in range(2):
            try:
                model = SARIMAX(candy, order = (p, d, q)).fit()
                if model.aic < best_aic:
                    best_aic = model.aic
                    print(p, d, q, model.aic, model.bic)
            except:
                pass

# %% [markdown]
# ## Descomposición de una serie estacional
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
model = SARIMAX(candy, order = (3, 1, 2)).fit()
prediction = model.get_forecast(steps = 24)
lower = prediction.conf_int()["lower production"]
upper = prediction.conf_int()["upper production"]
fig, ax = plt.subplots()
candy.truncate(before = "2005").plot(ax = ax)
prediction.predicted_mean.plot(ax = ax)
ax.fill_between(lower.index, lower, upper, alpha = 0.4)
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
components = seasonal_decompose(candy.to_timestamp())

# %%
components.plot()

# %% [markdown]
# ## El modelo SARIMA
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;ARIMA(2, 0, 1):&nbsp;&nbsp;&nbsp;y<sub>t</sub> = a<sub>1</sub>y<sub>t-1</sub> + a<sub>2</sub>y<sub>t-2</sub> + m<sub>1</sub>&epsilon;<sub>t-1</sub> + &epsilon;<sub>t</sub>
#
# SARIMA(0, 0, 0)(2, 0, 1)<sub>7</sub>:&nbsp;&nbsp;&nbsp;y<sub>t</sub> = a<sub>7</sub>y<sub>t-7</sub> + a<sub>14</sub>y<sub>t-14</sub> + m<sub>7</sub>&epsilon;<sub>t-7</sub> + &epsilon;<sub>t</sub>
#
# model = SARIMAX(dataframe, order = (p, i, q), seasonal_order = (P, I, Q, S), trend = "c")

# %%
model = SARIMAX(candy.to_timestamp(), order = (3, 1, 2), seasonal_order = (1,1,2,12), trend = "c").fit()
# Out:
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:949: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/sarimax.py:961: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /home/carcrupe/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:512: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# Convendrá convertir el índice del dataframe a timestamp para evitar problemas con la función plot_diagnostics...

# %% [markdown]
# Candy - SARIMA(3,1,2)(1, 1, 2, 12):

# %%
prediction = model.get_forecast(steps = 24)

# %%
lower = prediction.conf_int()["lower Production"]
upper = prediction.conf_int()["upper Production"]

# %%
candy.truncate(before = "2010").plot()
prediction.predicted_mean.plot()
plt.fill_between(lower.index, lower, upper, alpha = 0.4)
plt.show()

# %% [markdown]
# ## Diagnóstico del modelo
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
model.resid.head()
# Out:
# Date
# 1972-01-01    85.694067
# 1972-02-01   -13.874725
# 1972-03-01    -5.797530
# 1972-04-01    -1.458922
# 1972-05-01     0.445136
# Freq: MS, dtype: float64

# %%
model.plot_diagnostics(figsize = (14, 8))
plt.show()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                         Production   No. Observations:                  548
# Model:             SARIMAX(3, 1, 2)x(1, 1, 2, 12)   Log Likelihood               -1467.552
# Date:                            Sat, 08 Feb 2020   AIC                           2955.103
# Time:                                    13:56:40   BIC                           2997.926
# Sample:                                01-01-1972   HQIC                          2971.858
#                                      - 08-01-2017
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.0001      0.004      0.042      0.967      -0.007       0.007
# ar.L1         -0.1052      0.189     -0.556      0.578      -0.476       0.265
# ar.L2          0.5893      0.134      4.384      0.000       0.326       0.853
# ar.L3          0.1614      0.046      3.518      0.000       0.072       0.251
# ma.L1         -0.1855      0.189     -0.981      0.327      -0.556       0.185
# ma.L2         -0.7388      0.172     -4.286      0.000      -1.077      -0.401
# ar.S.L12       0.0340      0.388      0.088      0.930      -0.726       0.793
# ma.S.L12      -0.6679      0.384     -1.739      0.082      -1.421       0.085
# ma.S.L24      -0.0930      0.277     -0.336      0.737      -0.636       0.450
# sigma2        13.8363      0.720     19.217      0.000      12.425      15.247
# ===================================================================================
# Ljung-Box (Q):                       85.44   Jarque-Bera (JB):                26.13
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.31   Skew:                            -0.26
# Prob(H) (two-sided):                  0.07   Kurtosis:                         3.95
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# ## Automatización del cálculo de los órdenes óptimos
# <div style = "float:right"><a style="text-decoration:none" href = "#inicio">Inicio</a></div>

# %%
! pip install pmdarima
# Out:
# Collecting pmdarima
#   Downloading https://files.pythonhosted.org/packages/1a/bd/fc357ead270a483fc1ecf8cf4da8f38bca767f14449a7821481a0bdd3366/pmdarima-1.5.2-cp37-cp37m-manylinux1_x86_64.whl (1.4MB)
#      |████████████████████████████████| 1.5MB 4.0MB/s eta 0:00:01
# Requirement already satisfied: Cython>=0.29 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.29.13)
# Requirement already satisfied: joblib>=0.11 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: statsmodels>=0.10.0 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.10.1)
# Requirement already satisfied: pandas>=0.19 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.25.1)
# Requirement already satisfied: numpy>=1.16 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.17.2)
# Requirement already satisfied: scipy>=1.3 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.3.1)
# Requirement already satisfied: scikit-learn>=0.19 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.21.3)
# Requirement already satisfied: patsy>=0.4.0 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from statsmodels>=0.10.0->pmdarima) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2.8.0)
# Requirement already satisfied: pytz>=2017.2 in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2019.3)
# Requirement already satisfied: six in /home/carcrupe/anaconda3/lib/python3.7/site-packages (from patsy>=0.4.0->statsmodels>=0.10.0->pmdarima) (1.12.0)
# Installing collected packages: pmdarima
# Successfully installed pmdarima-1.5.2

# %%
import pmdarima as pm

# %% [markdown]
# http://alkaline-ml.com/pmdarima/1.0.0/modules/generated/pmdarima.arima.auto_arima.html

# %%
model = pm.auto_arima(
    candy,
    m = 12,
    suppress_warnings=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-327-9f16d879efeb> in <module>
#       2     candy,
#       3     m = 12,
# ----> 4     suppress_warnings=True
#       5 )
#
# ~/anaconda3/lib/python3.7/site-packages/pmdarima/arima/auto.py in auto_arima(y, exogenous, start_p, d, start_q, max_p, max_d, max_q, start_P, D, start_Q, max_P, max_D, max_Q, max_order, m, seasonal, stationary, information_criterion, alpha, test, seasonal_test, stepwise, n_jobs, start_params, trend, method, maxiter, offset_test_args, seasonal_test_args, suppress_warnings, error_action, trace, random, random_state, n_fits, return_valid_fits, out_of_sample_size, scoring, scoring_args, with_intercept, sarimax_kwargs, **fit_args)
#     577
#     578         # do the step-through...
# --> 579         all_res = stepwise_wrapper.solve_stepwise()
#     580
#     581     # filter the non-successful ones
#
# ~/anaconda3/lib/python3.7/site-packages/pmdarima/arima/_auto_solvers.py in solve_stepwise(self)
#     225             if P > 0 and \
#     226                     self.k < self.max_k and \
# --> 227                     self._do_fit((p, d, q), (P - 1, D, Q, m)):
#     228                 P -= 1
#     229                 continue
#
# ~/anaconda3/lib/python3.7/site-packages/pmdarima/arima/_auto_solvers.py in _do_fit(self, order, seasonal_order, constant)
#     156                 order=order,
#     157                 seasonal_order=seasonal_order,
# --> 158                 with_intercept=constant)
#     159
#     160             # use the orders as a key to be hashed for
#
# ~/anaconda3/lib/python3.7/site-packages/pmdarima/arima/_auto_solvers.py in _fit_arima(x, xreg, order, seasonal_order, start_params, trend, method, maxiter, fit_params, suppress_warnings, trace, error_action, out_of_sample_size, scoring, scoring_args, with_intercept, **kwargs)
#     351                     scoring_args=scoring_args,
#     352                     with_intercept=with_intercept, **kwargs)\
# --> 353             .fit(x, exogenous=xreg, **fit_params)
#     354
#     355     # for non-stationarity errors or singular matrices, return None
#
# ~/anaconda3/lib/python3.7/site-packages/pmdarima/arima/arima.py in fit(self, y, exogenous, **fit_args)
#     463
#     464         # Internal call
# --> 465         self._fit(y, exogenous, **fit_args)
#     466
#     467         # now make a forecast if we're validating to compute the
#
# ~/anaconda3/lib/python3.7/site-packages/pmdarima/arima/arima.py in _fit(self, y, exogenous, **fit_args)
#     387             with warnings.catch_warnings(record=False):
#     388                 warnings.simplefilter('ignore')
# --> 389                 fit, self.arima_res_ = _fit_wrapper()
#     390         else:
#     391             fit, self.arima_res_ = _fit_wrapper()
#
# ~/anaconda3/lib/python3.7/site-packages/pmdarima/arima/arima.py in _fit_wrapper()
#     381                                     maxiter=_maxiter,
#     382                                     disp=disp,
# --> 383                                     **fit_args)
#     384
#     385         # sometimes too many warnings...
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     480                                            full_output=full_output,
#     481                                            disp=disp, callback=callback,
# --> 482                                            skip_hessian=True, **kwargs)
#     483
#     484         # Just return the fitted parameters if requested
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in fit(self, start_params, method, maxiter, full_output, disp, fargs, callback, retall, skip_hessian, **kwargs)
#     468                                                        callback=callback,
#     469                                                        retall=retall,
# --> 470                                                        full_output=full_output)
#     471
#     472         # NOTE: this is for fit_regularized and should be generalized
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit(self, objective, gradient, start_params, fargs, kwargs, hessian, method, maxiter, full_output, disp, callback, retall)
#     217                             disp=disp, maxiter=maxiter, callback=callback,
#     218                             retall=retall, full_output=full_output,
# --> 219                             hess=hessian)
#     220
#     221         optim_settings = {'optimizer': method, 'start_params': start_params,
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/optimizer.py in _fit_lbfgs(f, score, start_params, fargs, kwargs, disp, maxiter, callback, retall, full_output, hess)
#     437                                      callback=callback, args=fargs,
#     438                                      bounds=bounds, disp=disp,
# --> 439                                      **extra_kwargs)
#     440
#     441     if full_output:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in fmin_l_bfgs_b(func, x0, fprime, args, approx_grad, bounds, m, factr, pgtol, epsilon, iprint, maxfun, maxiter, disp, callback, maxls)
#     197
#     198     res = _minimize_lbfgsb(fun, x0, args=args, jac=jac, bounds=bounds,
# --> 199                            **opts)
#     200     d = {'grad': res['jac'],
#     201          'task': res['message'],
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, **unknown_options)
#     333             # until the completion of the current minimization iteration.
#     334             # Overwrite f and g:
# --> 335             f, g = func_and_grad(x)
#     336         elif task_str.startswith(b'NEW_X'):
#     337             # new iteration
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/lbfgsb.py in func_and_grad(x)
#     279         def func_and_grad(x):
#     280             f = fun(x, *args)
# --> 281             g = _approx_fprime_helper(x, fun, epsilon, args=args, f0=f)
#     282             return f, g
#     283     else:
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in _approx_fprime_helper(xk, f, epsilon, args, f0)
#     694         ei[k] = 1.0
#     695         d = epsilon * ei
# --> 696         grad[k] = (f(*((xk + d,) + args)) - f0) / d[k]
#     697         ei[k] = 0.0
#     698     return grad
#
# ~/anaconda3/lib/python3.7/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in f(params, *args)
#     442
#     443         def f(params, *args):
# --> 444             return -self.loglike(params, *args) / nobs
#     445
#     446         if method == 'newton':
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/mlemodel.py in loglike(self, params, *args, **kwargs)
#     657             kwargs['inversion_method'] = INVERT_UNIVARIATE | SOLVE_LU
#     658
# --> 659         loglike = self.ssm.loglike(complex_step=complex_step, **kwargs)
#     660
#     661         # Koopman, Shephard, and Doornik recommend maximizing the average
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/kalman_filter.py in loglike(self, **kwargs)
#     873                                ' MEMORY_NO_LIKELIHOOD option is selected.')
#     874         kwargs['conserve_memory'] = MEMORY_CONSERVE ^ MEMORY_NO_LIKELIHOOD
# --> 875         kfilter = self._filter(**kwargs)
#     876         loglikelihood_burn = kwargs.get('loglikelihood_burn',
#     877                                         self.loglikelihood_burn)
#
# ~/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/statespace/kalman_filter.py in _filter(self, filter_method, inversion_method, stability_method, conserve_memory, filter_timing, tolerance, loglikelihood_burn, complex_step)
#     800
#     801         # Run the filter
# --> 802         kfilter()
#     803
#     804         return kfilter
#
# KeyboardInterrupt:

# %%
model.summary()

# %%
fig = model.plot_diagnostics()
fig.set_size_inches(15, 9)
plt.show()

# %%
forecast_mean, conf_int = model.predict(24, return_conf_int = True)

# %%
forecast_lower = conf_int[:, 0]
forecast_upper = conf_int[:, 1]

# %%
dates = pd.period_range(start = candy.index[-1], periods = 25, freq = "M")[1:]
dates

# %%
forecast = pd.Series(forecast_mean, index = dates)

# %%
fig, ax = plt.subplots()
candy.truncate(before = "2010").plot(ax = ax)
forecast.plot(ax = ax, color = "red")
plt.fill_between(dates, forecast_lower, forecast_upper, color = "lightblue", alpha = 0.6)
plt.show()
